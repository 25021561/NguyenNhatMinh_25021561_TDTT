# %% [markdown]
# # Thực hành 13

# %% [markdown]
# ### Câu 1
# #### Cho một danh sách các số có độ dài n, hãy trả về phần tử lớn nhất và phần tử nhỏ nhất.
#
# **Task:** Viết một hàm trả về một tuple `(max_value, min_value)`.
#
# **Constraints/Notes:** Danh sách đầu vào không được rỗng; nếu danh sách rỗng, trả về lỗi `ValueError`.

# %%
# Code ở đây

# %%
# Tests

assert max_and_min([1, 2, 3, 4, 5]) == (5, 1)
assert max_and_min([5]) == (5, 5)
assert max_and_min([-2, -5, -1]) == (-1, -5)
assert max_and_min([0, 0, 0]) == (0, 0)
assert max_and_min([10, -10, 3.5, 3.4]) == (10, -10)

try:
    max_and_min([])
    assert False, "Expected ValueError for empty input"
except ValueError:
    pass
print ("All Test passed!")

# %% [markdown]
# ### Câu 2
# #### Cho một danh sách các số có độ dài *n*, in ra ba số nhỏ nhất theo thứ tự tăng dần.
#
# **Task:** Viết một hàm trả về một danh sách gồm 3 giá trị nhỏ nhất được sắp xếp tăng dần.
#
# **Constraints/Notes:** Giả định `len(nums) >= 3`. Nếu không, trả về lỗi `ValueError`.

# %%
# Nhập code ở đây

# %%
# Tests

assert three_smallest([]) == []
assert three_smallest([5, 1, 4, 2, 3]) == [1, 2, 3]
assert three_smallest([3, 3, 3, 3]) == [3, 3, 3]
assert three_smallest([-1, -5, 0, 2]) == [-5, -1, 0]
assert three_smallest([10, 9, 8, 7, 6, 5]) == [5, 6, 7]
assert three_smallest([1.2, 1.1, 1.15, 9.0, -2.0]) == [-2.0, 1.1, 1.15]

try:
    three_smallest([1, 2])
    assert False, "Expected ValueError for length < 3"
except ValueError:
    pass

print("Passed all tests!")

# %% [markdown]
# ### Câu 3
# #### Cho một danh sách các số nguyên dương, in ra (trả về) giá trị lớn thứ hai và giá trị nhỏ thứ hai.
#
# **Task:** Viết một hàm trả về `(second_largest, second_smallest)`.
#
# **Note on duplicates:** Sử dụng các giá trị **phân biệt** (vd trong dãy `[1,1,2]`, không tồn tại giá trị nhỏ nhất thứ nhì).
# Trả về lỗi `ValueError` nếu có ít hơn 2 giá trị phân biệt.

# %%
# Nhập code ở đây

# %%
# Tests

assert second_largest_and_second_smallest([1, 2, 3, 4, 5]) == (4, 2)
assert second_largest_and_second_smallest([5, 4, 3, 2, 1]) == (4, 2)
assert second_largest_and_second_smallest([10, 10, 9, 9, 8]) == (9, 9)
assert second_largest_and_second_smallest([2, 100]) == (2, 100)
assert second_largest_and_second_smallest([1, 2, 2, 3, 3, 4]) == (3, 2)

for bad in ([7], [7, 7, 7]):
    try:
        print(bad)
        second_largest_and_second_smallest(bad)
        assert False, "Expected ValueError for fewer than 2 distinct values"
    except ValueError:
        pass
print("Passed all Test!")

# %% [markdown]
# ### Câu 4
# #### Cho 2 dãy `a` và `b` có độ dài bằng nhau, kiểm tra xem chúng có các phần tử giống nhau hay không ? (thứ tự không quan trọng).
#
# Ví dụ: `[1,2,3,4,5]` và `[5,4,3,2,1]` → `True`
#
# **Task:** Viết một hàm trả về `True` nếu thỏa mãn đề bài, ngược lại trả về `False`.
#
# **Constraints/Notes:** Độ dài 2 dãy là bằng nhau; nếu không, trả về `False`.

# %%
# Nhập code

# %%
# Tests
assert same_elements([1, 2, 3, 4, 5], [5, 4, 3, 2, 1]) is True
assert same_elements([1, 2, 2, 3], [2, 1, 3, 2]) is True
assert same_elements([1, 2, 2, 3], [1, 2, 3, 3]) is False
assert same_elements([], []) is True
assert same_elements([1], [2]) is False
assert same_elements([1, 2], [1]) is False  # different lengths

# %% [markdown]
# ### Câu 5
# #### Cho một mảng các số, kiểm tra xem nó có phải là dãy tăng dần chặt chẽ hay không.
#
# **Task:** Viết một hàm trả về `True` nếu `nums[i] < nums[i+1]` với tất cả `i`, ngược lại trả về `False`.
#
# **Notes:** Một danh sách rỗng hoặc danh sách chỉ có một phần tử được coi là tăng dần.

# %%
#your code

# %%
# Tests
assert is_strictly_increasing([]) is True
assert is_strictly_increasing([5]) is True
assert is_strictly_increasing([1, 2, 3, 4]) is True
assert is_strictly_increasing([1, 1, 2]) is False
assert is_strictly_increasing([4, 3, 2, 1]) is False
assert is_strictly_increasing([-3, -2, -1, 0, 10]) is True

# %% [markdown]
# ### Câu 6
# #### Cho một danh sách các số nguyên dương và một số nguyên dương `x`, trả về số chẵn lớn thứ x trong danh sách.
#
# Ví dụ:
# - `nums = [1,2,3,4,5]`, `x = 2` → `2` (số chẵn lớn nhất là 4, số chẵn lớn thứ 2 là 2)
#
# **Task:** Viết một hàm trả về giá trị chẵn lớn thứ x.

# %%
#your code

# %%
# Tests
assert kth_largest_even([1, 2, 3, 4, 5], 1) == 4
assert kth_largest_even([1, 2, 3, 4, 5], 2) == 2
assert kth_largest_even([8, 6, 4, 2], 3) == 4
assert kth_largest_even([2, 2, 2], 2) == 2
assert kth_largest_even([100, 1, 50, 3, 4], 2) == 50

# %% [markdown]
# ### Câu 7
# #### Tìm kiếm
# Cho một danh sách các số đã được sắp xếp theo thứ tự tăng dần, xác định xem số `x` có nằm trong danh sách hay không và trả về chỉ số của nó.
#
# **Task:** Viết một hàm trả về chỉ số của `x` nếu tìm thấy, ngược lại trả về `-1`.
#
# **Notes:** Nếu có các giá trị trùng lặp, trả về kết quả khớp đầu tiên.

# %%
#your code

# %%
# Tests
assert linear_search([1, 3, 5, 7, 9], 1) == 0
assert linear_search([1, 3, 5, 7, 9], 9) == 4
assert linear_search([1, 3, 5, 7, 9], 6) == -1
assert linear_search([], 10) == -1
assert linear_search([2, 2, 2, 3], 2) == 0  # first match
assert linear_search([10, 20, 30], 5) == -1  # early stop case

# %% [markdown]
# ### Câu 8
# #### Tìm kiếm nhị phân
# Cho một danh sách các số đã được sắp xếp theo thứ tự tăng dần, xác định xem số `x` có nằm trong danh sách hay không và trả về chỉ số của nó.
#
# **Task:** Viết một hàm trả về chỉ số của `x` nếu tìm thấy, ngược lại trả về `-1`.
#
# **Notes:** Nếu có các giá trị trùng lặp, trả về bất kỳ chỉ số hợp lệ nào cũng được chấp nhận.

# %%
#your code

# %%
# Tests
assert binary_search([1, 3, 5, 7, 9], 1) == 0
assert binary_search([1, 3, 5, 7, 9], 9) == 4
assert binary_search([1, 3, 5, 7, 9], 6) == -1
assert binary_search([], 10) == -1

idx = binary_search([2, 2, 2, 3], 2)
assert idx in (0, 1, 2)

assert binary_search([10, 20, 30, 40], 35) == -1
